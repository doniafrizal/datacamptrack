# %% [markdown]
# Crime Sampler Using Dataset From Chicago Police
# by csv.reader method

# %% [markdown]
# Import necessary library

# %%
# Import the csv module
import csv

# Import the pendulum module for datetime manipulation
import pendulum

# Import Counter, defaultdict from collections module
from collections import Counter
from collections import defaultdict

# Import the datetime module
from datetime import datetime

# %% [markdown]
# Open Crime Sampler dataset using csv import

# %%
# Create the file object: csvfile
csv_file = open('Crimes2018.csv','r')

# Create a dictionary that defaults to a list: crimes_by_district
crimes_by_district = defaultdict(list)

# %% [markdown]
# Read crime_sampler.csv line by line, then convert it to crime_data list

# %%
# Loop over a DictReader of the CSV file
for row in csv.DictReader(csv_file):
    # Pop the district from each row: district
    district = row.pop('District')
    # Append the rest of the data to the list for proper district in crimes_by_district
    crimes_by_district[district].append(row)

# %%
crimes_by_district['011']
# Out:
# [OrderedDict([('ID', '11357114'),
#               ('Case Number', 'JB319290'),
#               ('Date', '06/01/2018 12:01:00 AM'),
#               ('Block', '047XX W JACKSON BLVD'),
#               ('IUCR', '1751'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description', 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1131'),
#               ('Ward', '28'),
#               ('Community Area', '25'),
#               ('FBI Code', '17'),
#               ('X Coordinate', '1144908'),
#               ('Y Coordinate', '1898272'),
#               ('Year', '2018'),
#               ('Updated On', '05/15/2020 03:48:40 PM'),
#               ('Latitude', '41.876865807'),
#               ('Longitude', '-87.743409103'),
#               ('Location', '(41.876865807, -87.743409103)')]),
#  OrderedDict([('ID', '11329831'),
#               ('Case Number', 'JB283175'),
#               ('Date', '05/29/2018 01:00:00 AM'),
#               ('Block', '034XX W FRANKLIN BLVD'),
#               ('IUCR', '0264'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'AGGRAVATED - OTHER DANGEROUS WEAPON'),
#               ('Location Description', 'VEHICLE NON-COMMERCIAL'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1153459'),
#               ('Y Coordinate', '1903123'),
#               ('Year', '2018'),
#               ('Updated On', '05/14/2020 03:48:33 PM'),
#               ('Latitude', '41.890011876'),
#               ('Longitude', '-87.711883222'),
#               ('Location', '(41.890011876, -87.711883222)')]),
#  OrderedDict([('ID', '11532873'),
#               ('Case Number', 'JB549819'),
#               ('Date', '12/08/2018 10:00:00 AM'),
#               ('Block', '011XX N LONG AVE'),
#               ('IUCR', '0281'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'NON-AGGRAVATED'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1524'),
#               ('Ward', '37'),
#               ('Community Area', '25'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1149775'),
#               ('Y Coordinate', '1905050'),
#               ('Year', '2018'),
#               ('Updated On', '05/05/2020 03:49:49 PM'),
#               ('Latitude', '41.895372185'),
#               ('Longitude', '-87.725362479'),
#               ('Location', '(41.895372185, -87.725362479)')]),
#  OrderedDict([('ID', '11406292'),
#               ('Case Number', 'JB383531'),
#               ('Date', '02/01/2018 12:00:00 AM'),
#               ('Block', '009XX N KEELER AVE'),
#               ('IUCR', '0266'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'PREDATORY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true'),
#               ('Beat', '1111'),
#               ('Ward', '37'),
#               ('Community Area', '23'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1148214'),
#               ('Y Coordinate', '1905815'),
#               ('Year', '2018'),
#               ('Updated On', '05/05/2020 03:49:49 PM'),
#               ('Latitude', '41.897501637'),
#               ('Longitude', '-87.731075978'),
#               ('Location', '(41.897501637, -87.731075978)')]),
#  OrderedDict([('ID', '11965653'),
#               ('Case Number', 'JD132788'),
#               ('Date', '04/12/2018 12:00:00 AM'),
#               ('Block', '039XX W VAN BUREN ST'),
#               ('IUCR', '1752'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description',
#                'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1132'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '17'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2020 03:47:28 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11965652'),
#               ('Case Number', 'JD132768'),
#               ('Date', '04/09/2018 12:00:00 AM'),
#               ('Block', '039XX W VAN BUREN ST'),
#               ('IUCR', '1754'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description',
#                'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1132'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '02'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2020 03:47:28 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11389008'),
#               ('Case Number', 'JB361207'),
#               ('Date', '07/21/2018 12:01:00 AM'),
#               ('Block', '026XX W JACKSON BLVD'),
#               ('IUCR', '0281'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'NON-AGGRAVATED'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1125'),
#               ('Ward', '28'),
#               ('Community Area', '28'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1158582'),
#               ('Y Coordinate', '1898590'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2020 03:47:28 PM'),
#               ('Latitude', '41.87746955'),
#               ('Longitude', '-87.693193389'),
#               ('Location', '(41.87746955, -87.693193389)')]),
#  OrderedDict([('ID', '11495229'),
#               ('Case Number', 'JB500008'),
#               ('Date', '11/02/2018 01:45:00 AM'),
#               ('Block', '041XX W ROOSEVELT RD'),
#               ('IUCR', '031A'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED - HANDGUN'),
#               ('Location Description', 'SMALL RETAIL STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '24'),
#               ('Community Area', '29'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1148772'),
#               ('Y Coordinate', '1894380'),
#               ('Year', '2018'),
#               ('Updated On', '04/30/2020 03:47:59 PM'),
#               ('Latitude', '41.866111947'),
#               ('Longitude', '-87.72932209'),
#               ('Location', '(41.866111947, -87.72932209)')]),
#  OrderedDict([('ID', '11290436'),
#               ('Case Number', 'JB230729'),
#               ('Date', '04/20/2018 04:30:00 AM'),
#               ('Block', '044XX W FIFTH AVE'),
#               ('IUCR', '0265'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'AGGRAVATED - OTHER'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1131'),
#               ('Ward', '24'),
#               ('Community Area', '26'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1146672'),
#               ('Y Coordinate', '1895701'),
#               ('Year', '2018'),
#               ('Updated On', '04/29/2020 03:53:17 PM'),
#               ('Latitude', '41.86977722'),
#               ('Longitude', '-87.736997747'),
#               ('Location', '(41.86977722, -87.736997747)')]),
#  OrderedDict([('ID', '11353516'),
#               ('Case Number', 'JB314372'),
#               ('Date', '06/19/2018 10:05:00 PM'),
#               ('Block', '040XX W MONROE ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'RESIDENCE - YARD (FRONT / BACK)'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1149465'),
#               ('Y Coordinate', '1899354'),
#               ('Year', '2018'),
#               ('Updated On', '04/25/2020 03:46:57 PM'),
#               ('Latitude', '41.879747768'),
#               ('Longitude', '-87.726648948'),
#               ('Location', '(41.879747768, -87.726648948)')]),
#  OrderedDict([('ID', '11294972'),
#               ('Case Number', 'JB236776'),
#               ('Date', '04/23/2018 09:31:00 PM'),
#               ('Block', '011XX N AVERS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1112'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1150511'),
#               ('Y Coordinate', '1907228'),
#               ('Year', '2018'),
#               ('Updated On', '04/19/2020 03:44:21 PM'),
#               ('Latitude', '41.901334494'),
#               ('Longitude', '-87.722602365'),
#               ('Location', '(41.901334494, -87.722602365)')]),
#  OrderedDict([('ID', '11388863'),
#               ('Case Number', 'JB361027'),
#               ('Date', '07/22/2018 10:33:00 PM'),
#               ('Block', '038XX W GLADYS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1150850'),
#               ('Y Coordinate', '1898081'),
#               ('Year', '2018'),
#               ('Updated On', '04/16/2020 03:45:11 PM'),
#               ('Latitude', '41.876227537'),
#               ('Longitude', '-87.721596698'),
#               ('Location', '(41.876227537, -87.721596698)')]),
#  OrderedDict([('ID', '11379681'),
#               ('Case Number', 'JB349063'),
#               ('Date', '07/14/2018 05:19:00 AM'),
#               ('Block', '007XX N RIDGEWAY AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1112'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1151257'),
#               ('Y Coordinate', '1904578'),
#               ('Year', '2018'),
#               ('Updated On', '04/15/2020 03:48:26 PM'),
#               ('Latitude', '41.894048023'),
#               ('Longitude', '-87.719931808'),
#               ('Location', '(41.894048023, -87.719931808)')]),
#  OrderedDict([('ID', '11332114'),
#               ('Case Number', 'JB285961'),
#               ('Date', '05/30/2018 09:23:00 PM'),
#               ('Block', '033XX W HARRISON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'GAS STATION'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '24'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1153993'),
#               ('Y Coordinate', '1897159'),
#               ('Year', '2018'),
#               ('Updated On', '04/15/2020 03:48:26 PM'),
#               ('Latitude', '41.873635421'),
#               ('Longitude', '-87.710081187'),
#               ('Location', '(41.873635421, -87.710081187)')]),
#  OrderedDict([('ID', '11266467'),
#               ('Case Number', 'JB199249'),
#               ('Date', '03/25/2018 02:40:00 PM'),
#               ('Block', '042XX W VAN BUREN ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1148115'),
#               ('Y Coordinate', '1897683'),
#               ('Year', '2018'),
#               ('Updated On', '04/15/2020 03:48:26 PM'),
#               ('Latitude', '41.875188431'),
#               ('Longitude', '-87.731649018'),
#               ('Location', '(41.875188431, -87.731649018)')]),
#  OrderedDict([('ID', '11202924'),
#               ('Case Number', 'JB114547'),
#               ('Date', '01/13/2018 03:55:00 AM'),
#               ('Block', '039XX W ARTHINGTON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '24'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1150249'),
#               ('Y Coordinate', '1895744'),
#               ('Year', '2018'),
#               ('Updated On', '04/15/2020 03:48:26 PM'),
#               ('Latitude', '41.869826277'),
#               ('Longitude', '-87.723864309'),
#               ('Location', '(41.869826277, -87.723864309)')]),
#  OrderedDict([('ID', '11370916'),
#               ('Case Number', 'JB337355'),
#               ('Date', '07/05/2018 11:56:00 PM'),
#               ('Block', '041XX W MADISON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1148697'),
#               ('Y Coordinate', '1899688'),
#               ('Year', '2018'),
#               ('Updated On', '04/14/2020 03:47:21 PM'),
#               ('Latitude', '41.880679165'),
#               ('Longitude', '-87.729460332'),
#               ('Location', '(41.880679165, -87.729460332)')]),
#  OrderedDict([('ID', '11349374'),
#               ('Case Number', 'JB308922'),
#               ('Date', '06/16/2018 02:13:00 AM'),
#               ('Block', '033XX W MONROE ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1124'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1154088'),
#               ('Y Coordinate', '1899336'),
#               ('Year', '2018'),
#               ('Updated On', '04/14/2020 03:47:21 PM'),
#               ('Latitude', '41.879607443'),
#               ('Longitude', '-87.709674313'),
#               ('Location', '(41.879607443, -87.709674313)')]),
#  OrderedDict([('ID', '11544476'),
#               ('Case Number', 'JB564699'),
#               ('Date', '12/23/2018 06:05:00 AM'),
#               ('Block', '043XX W GLADYS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1131'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1147580'),
#               ('Y Coordinate', '1898003'),
#               ('Year', '2018'),
#               ('Updated On', '04/12/2020 03:46:59 PM'),
#               ('Latitude', '41.876076824'),
#               ('Longitude', '-87.733605134'),
#               ('Location', '(41.876076824, -87.733605134)')]),
#  OrderedDict([('ID', '11426558'),
#               ('Case Number', 'JB409172'),
#               ('Date', '08/25/2018 08:00:00 PM'),
#               ('Block', '042XX W MADISON ST'),
#               ('IUCR', '0610'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'OTHER (SPECIFY)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '05'),
#               ('X Coordinate', '1148070'),
#               ('Y Coordinate', '1899674'),
#               ('Year', '2018'),
#               ('Updated On', '04/12/2020 03:46:59 PM'),
#               ('Latitude', '41.88065283'),
#               ('Longitude', '-87.731763004'),
#               ('Location', '(41.88065283, -87.731763004)')]),
#  OrderedDict([('ID', '11562911'),
#               ('Case Number', 'JC111965'),
#               ('Date', '12/24/2018 12:00:00 PM'),
#               ('Block', '041XX W MAYPOLE AVE'),
#               ('IUCR', '1752'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description',
#                'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1114'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '17'),
#               ('X Coordinate', '1148826'),
#               ('Y Coordinate', '1901133'),
#               ('Year', '2018'),
#               ('Updated On', '04/11/2020 03:46:35 PM'),
#               ('Latitude', '41.884641914'),
#               ('Longitude', '-87.728949284'),
#               ('Location', '(41.884641914, -87.728949284)')]),
#  OrderedDict([('ID', '11535870'),
#               ('Case Number', 'JB554004'),
#               ('Date', '12/15/2018 03:08:00 AM'),
#               ('Block', '043XX W LAKE ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1114'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1147392'),
#               ('Y Coordinate', '1901597'),
#               ('Year', '2018'),
#               ('Updated On', '04/07/2020 03:48:40 PM'),
#               ('Latitude', '41.885942776'),
#               ('Longitude', '-87.734203288'),
#               ('Location', '(41.885942776, -87.734203288)')]),
#  OrderedDict([('ID', '12023323'),
#               ('Case Number', 'JD201472'),
#               ('Date', '06/18/2018 09:00:00 AM'),
#               ('Block', '040XX W WILCOX ST'),
#               ('IUCR', '1153'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '11'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '04/04/2020 03:46:15 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11446510'),
#               ('Case Number', 'JB435926'),
#               ('Date', '09/14/2018 10:13:00 PM'),
#               ('Block', '007XX S INDEPENDENCE BLVD'),
#               ('IUCR', '0453'),
#               ('Primary Type', 'BATTERY'),
#               ('Description',
#                'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '24'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1151217'),
#               ('Y Coordinate', '1896348'),
#               ('Year', '2018'),
#               ('Updated On', '04/04/2020 03:44:34 PM'),
#               ('Latitude', '41.871464806'),
#               ('Longitude', '-87.720294635'),
#               ('Location', '(41.871464806, -87.720294635)')]),
#  OrderedDict([('ID', '11977648'),
#               ('Case Number', 'JD147303'),
#               ('Date', '04/11/2018 07:00:00 AM'),
#               ('Block', '042XX W AUGUSTA BLVD'),
#               ('IUCR', '1754'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description',
#                'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1111'),
#               ('Ward', '37'),
#               ('Community Area', '23'),
#               ('FBI Code', '02'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '03/31/2020 03:47:00 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11459481'),
#               ('Case Number', 'JB452882'),
#               ('Date', '09/27/2018 11:42:00 AM'),
#               ('Block', '030XX W FLOURNOY ST'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSSESS - HEROIN (WHITE)'),
#               ('Location Description', 'RESIDENCE - YARD (FRONT / BACK)'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1156224'),
#               ('Y Coordinate', '1896878'),
#               ('Year', '2018'),
#               ('Updated On', '03/31/2020 03:47:00 PM'),
#               ('Latitude', '41.872819583'),
#               ('Longitude', '-87.701897602'),
#               ('Location', '(41.872819583, -87.701897602)')]),
#  OrderedDict([('ID', '11402097'),
#               ('Case Number', 'JB377942'),
#               ('Date', '08/03/2018 07:16:00 PM'),
#               ('Block', '004XX S KEDZIE AVE'),
#               ('IUCR', '0326'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'AGGRAVATED VEHICULAR HIJACKING'),
#               ('Location Description',
#                'PARKING LOT / GARAGE (NON RESIDENTIAL)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1155110'),
#               ('Y Coordinate', '1897771'),
#               ('Year', '2018'),
#               ('Updated On', '03/29/2020 03:43:48 PM'),
#               ('Latitude', '41.875292483'),
#               ('Longitude', '-87.705963666'),
#               ('Location', '(41.875292483, -87.705963666)')]),
#  OrderedDict([('ID', '12018781'),
#               ('Case Number', 'JD196163'),
#               ('Date', '05/07/2018 09:45:00 AM'),
#               ('Block', '027XX W LEXINGTON ST'),
#               ('IUCR', '1153'),
#               ('Primary Type', 'DECEPTIVE PRACTICE'),
#               ('Description', 'FINANCIAL IDENTITY THEFT OVER $ 300'),
#               ('Location Description', ''),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1135'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '11'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '03/28/2020 03:49:09 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11402425'),
#               ('Case Number', 'JB378425'),
#               ('Date', '08/04/2018 04:00:00 AM'),
#               ('Block', '034XX W HURON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1153137'),
#               ('Y Coordinate', '1904450'),
#               ('Year', '2018'),
#               ('Updated On', '03/26/2020 03:45:12 PM'),
#               ('Latitude', '41.893659689'),
#               ('Longitude', '-87.713030526'),
#               ('Location', '(41.893659689, -87.713030526)')]),
#  OrderedDict([('ID', '11443826'),
#               ('Case Number', 'JB431991'),
#               ('Date', '09/12/2018 06:12:00 AM'),
#               ('Block', '034XX W WALNUT ST'),
#               ('IUCR', '0265'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'AGGRAVATED - OTHER'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1123'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1153460'),
#               ('Y Coordinate', '1901460'),
#               ('Year', '2018'),
#               ('Updated On', '03/25/2020 03:45:43 PM'),
#               ('Latitude', '41.885448417'),
#               ('Longitude', '-87.711923777'),
#               ('Location', '(41.885448417, -87.711923777)')]),
#  OrderedDict([('ID', '11345919'),
#               ('Case Number', 'JB304384'),
#               ('Date', '06/12/2018 08:36:00 PM'),
#               ('Block', '009XX N CENTRAL PARK AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'RESIDENCE - PORCH / HALLWAY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1112'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1152211'),
#               ('Y Coordinate', '1905971'),
#               ('Year', '2018'),
#               ('Updated On', '03/25/2020 03:45:43 PM'),
#               ('Latitude', '41.897851784'),
#               ('Longitude', '-87.71639126'),
#               ('Location', '(41.897851784, -87.71639126)')]),
#  OrderedDict([('ID', '11302094'),
#               ('Case Number', 'JB246088'),
#               ('Date', '05/01/2018 09:45:00 PM'),
#               ('Block', '033XX W GLADYS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1154004'),
#               ('Y Coordinate', '1898094'),
#               ('Year', '2018'),
#               ('Updated On', '03/25/2020 03:45:43 PM'),
#               ('Latitude', '41.87620094'),
#               ('Longitude', '-87.71001587'),
#               ('Location', '(41.87620094, -87.71001587)')]),
#  OrderedDict([('ID', '11274147'),
#               ('Case Number', 'JB208993'),
#               ('Date', '04/02/2018 06:44:00 PM'),
#               ('Block', '040XX W CONGRESS PKWY'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'ALLEY'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1149497'),
#               ('Y Coordinate', '1897385'),
#               ('Year', '2018'),
#               ('Updated On', '03/25/2020 03:45:43 PM'),
#               ('Latitude', '41.874343989'),
#               ('Longitude', '-87.726582558'),
#               ('Location', '(41.874343989, -87.726582558)')]),
#  OrderedDict([('ID', '11267806'),
#               ('Case Number', 'JB201105'),
#               ('Date', '03/27/2018 03:05:00 AM'),
#               ('Block', '007XX S CICERO AVE'),
#               ('IUCR', '031A'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED - HANDGUN'),
#               ('Location Description', 'GAS STATION'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1131'),
#               ('Ward', '24'),
#               ('Community Area', '25'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1144511'),
#               ('Y Coordinate', '1896107'),
#               ('Year', '2018'),
#               ('Updated On', '03/25/2020 03:45:43 PM'),
#               ('Latitude', '41.870932257'),
#               ('Longitude', '-87.744921277'),
#               ('Location', '(41.870932257, -87.744921277)')]),
#  OrderedDict([('ID', '11275321'),
#               ('Case Number', 'JB210509'),
#               ('Date', '04/03/2018 10:38:00 PM'),
#               ('Block', '034XX W ARTHINGTON ST'),
#               ('IUCR', '0610'),
#               ('Primary Type', 'BURGLARY'),
#               ('Description', 'FORCIBLE ENTRY'),
#               ('Location Description', 'OTHER (SPECIFY)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '24'),
#               ('Community Area', '29'),
#               ('FBI Code', '05'),
#               ('X Coordinate', '1153516'),
#               ('Y Coordinate', '1895827'),
#               ('Year', '2018'),
#               ('Updated On', '03/24/2020 03:47:26 PM'),
#               ('Latitude', '41.86998976'),
#               ('Longitude', '-87.711867914'),
#               ('Location', '(41.86998976, -87.711867914)')]),
#  OrderedDict([('ID', '11606705'),
#               ('Case Number', 'JC165498'),
#               ('Date', '12/27/2018 10:00:00 AM'),
#               ('Block', '007XX S ALBANY AVE'),
#               ('IUCR', '1562'),
#               ('Primary Type', 'SEX OFFENSE'),
#               ('Description', 'AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '17'),
#               ('X Coordinate', ''),
#               ('Y Coordinate', ''),
#               ('Year', '2018'),
#               ('Updated On', '03/23/2020 03:47:32 PM'),
#               ('Latitude', ''),
#               ('Longitude', ''),
#               ('Location', '')]),
#  OrderedDict([('ID', '11548520'),
#               ('Case Number', 'JB569095'),
#               ('Date', '12/27/2018 10:00:00 AM'),
#               ('Block', '007XX S ALBANY AVE'),
#               ('IUCR', '1751'),
#               ('Primary Type', 'OFFENSE INVOLVING CHILDREN'),
#               ('Description', 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '17'),
#               ('X Coordinate', '1155811'),
#               ('Y Coordinate', '1896709'),
#               ('Year', '2018'),
#               ('Updated On', '03/23/2020 03:47:32 PM'),
#               ('Latitude', '41.872364156'),
#               ('Longitude', '-87.703418476'),
#               ('Location', '(41.872364156, -87.703418476)')]),
#  OrderedDict([('ID', '11291926'),
#               ('Case Number', 'JB232815'),
#               ('Date', '04/21/2018 07:38:00 PM'),
#               ('Block', '035XX W POLK ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '24'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1152870'),
#               ('Y Coordinate', '1896140'),
#               ('Year', '2018'),
#               ('Updated On', '03/22/2020 03:46:35 PM'),
#               ('Latitude', '41.870861476'),
#               ('Longitude', '-87.714231302'),
#               ('Location', '(41.870861476, -87.714231302)')]),
#  OrderedDict([('ID', '11471800'),
#               ('Case Number', 'JB469226'),
#               ('Date', '10/01/2018 12:00:00 PM'),
#               ('Block', '002XX N KILBOURN AVE'),
#               ('IUCR', '1562'),
#               ('Primary Type', 'SEX OFFENSE'),
#               ('Description', 'AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1113'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '17'),
#               ('X Coordinate', '1153156'),
#               ('Y Coordinate', '1904451'),
#               ('Year', '2018'),
#               ('Updated On', '03/21/2020 03:44:56 PM'),
#               ('Latitude', '41.893662056'),
#               ('Longitude', '-87.712960719'),
#               ('Location', '(41.893662056, -87.712960719)')]),
#  OrderedDict([('ID', '11403565'),
#               ('Case Number', 'JB379835'),
#               ('Date', '08/05/2018 02:26:00 AM'),
#               ('Block', '047XX W GLADYS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'RESIDENCE - YARD (FRONT / BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1131'),
#               ('Ward', '28'),
#               ('Community Area', '25'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1144798'),
#               ('Y Coordinate', '1897934'),
#               ('Year', '2018'),
#               ('Updated On', '03/21/2020 03:44:56 PM'),
#               ('Latitude', '41.875940367'),
#               ('Longitude', '-87.743821518'),
#               ('Location', '(41.875940367, -87.743821518)')]),
#  OrderedDict([('ID', '11294549'),
#               ('Case Number', 'JB236162'),
#               ('Date', '04/24/2018 02:28:00 PM'),
#               ('Block', '010XX N AVERS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1112'),
#               ('Ward', '37'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1150531'),
#               ('Y Coordinate', '1906569'),
#               ('Year', '2018'),
#               ('Updated On', '03/21/2020 03:44:56 PM'),
#               ('Latitude', '41.899525741'),
#               ('Longitude', '-87.722546136'),
#               ('Location', '(41.899525741, -87.722546136)')]),
#  OrderedDict([('ID', '11542523'),
#               ('Case Number', 'JB562075'),
#               ('Date', '12/21/2018 07:20:00 AM'),
#               ('Block', '033XX W HURON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1154167'),
#               ('Y Coordinate', '1904471'),
#               ('Year', '2018'),
#               ('Updated On', '03/19/2020 03:44:13 PM'),
#               ('Latitude', '41.893696819'),
#               ('Longitude', '-87.709247108'),
#               ('Location', '(41.893696819, -87.709247108)')]),
#  OrderedDict([('ID', '11513303'),
#               ('Case Number', 'JB523990'),
#               ('Date', '11/11/2018 12:00:00 AM'),
#               ('Block', '007XX S CICERO AVE'),
#               ('IUCR', '0281'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'NON-AGGRAVATED'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1131'),
#               ('Ward', '24'),
#               ('Community Area', '25'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1144511'),
#               ('Y Coordinate', '1896107'),
#               ('Year', '2018'),
#               ('Updated On', '03/19/2020 03:44:13 PM'),
#               ('Latitude', '41.870932257'),
#               ('Longitude', '-87.744921277'),
#               ('Location', '(41.870932257, -87.744921277)')]),
#  OrderedDict([('ID', '11405627'),
#               ('Case Number', 'JB382593'),
#               ('Date', '08/06/2018 11:27:00 PM'),
#               ('Block', '034XX W LEXINGTON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '24'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1153597'),
#               ('Y Coordinate', '1896490'),
#               ('Year', '2018'),
#               ('Updated On', '03/19/2020 03:44:13 PM'),
#               ('Latitude', '41.871807494'),
#               ('Longitude', '-87.711552906'),
#               ('Location', '(41.871807494, -87.711552906)')]),
#  OrderedDict([('ID', '11195524'),
#               ('Case Number', 'JB104520'),
#               ('Date', '01/04/2018 05:20:00 PM'),
#               ('Block', '007XX S PULASKI RD'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'VACANT LOT / LAND'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '24'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1149836'),
#               ('Y Coordinate', '1896323'),
#               ('Year', '2018'),
#               ('Updated On', '03/19/2020 03:44:13 PM'),
#               ('Latitude', '41.871423156'),
#               ('Longitude', '-87.72536551'),
#               ('Location', '(41.871423156, -87.72536551)')]),
#  OrderedDict([('ID', '11543935'),
#               ('Case Number', 'JB563946'),
#               ('Date', '12/22/2018 02:30:00 PM'),
#               ('Block', '007XX N TRUMBULL AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1153249'),
#               ('Y Coordinate', '1904619'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.894121219'),
#               ('Longitude', '-87.712614696'),
#               ('Location', '(41.894121219, -87.712614696)')]),
#  OrderedDict([('ID', '11536742'),
#               ('Case Number', 'JB555209'),
#               ('Date', '12/16/2018 01:40:00 AM'),
#               ('Block', '045XX W WASHINGTON BLVD'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1113'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1146107'),
#               ('Y Coordinate', '1900111'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.881889541'),
#               ('Longitude', '-87.738959929'),
#               ('Location', '(41.881889541, -87.738959929)')]),
#  OrderedDict([('ID', '11530651'),
#               ('Case Number', 'JB546951'),
#               ('Date', '12/10/2018 12:00:00 AM'),
#               ('Block', '042XX W JACKSON BLVD'),
#               ('IUCR', '0281'),
#               ('Primary Type', 'CRIMINAL SEXUAL ASSAULT'),
#               ('Description', 'NON-AGGRAVATED'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '02'),
#               ('X Coordinate', '1148236'),
#               ('Y Coordinate', '1898350'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.877016428'),
#               ('Longitude', '-87.73118757'),
#               ('Location', '(41.877016428, -87.73118757)')]),
#  OrderedDict([('ID', '11527904'),
#               ('Case Number', 'JB543144'),
#               ('Date', '12/07/2018 12:36:00 AM'),
#               ('Block', '006XX N HOMAN AVE'),
#               ('IUCR', '033A'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ATTEMPT ARMED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1153601'),
#               ('Y Coordinate', '1903965'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.892319584'),
#               ('Longitude', '-87.711339316'),
#               ('Location', '(41.892319584, -87.711339316)')]),
#  OrderedDict([('ID', '11526391'),
#               ('Case Number', 'JB541114'),
#               ('Date', '12/05/2018 12:53:00 PM'),
#               ('Block', '010XX N AVERS AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1112'),
#               ('Ward', '37'),
#               ('Community Area', '23'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1150530'),
#               ('Y Coordinate', '1906617'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.899657478'),
#               ('Longitude', '-87.722548554'),
#               ('Location', '(41.899657478, -87.722548554)')]),
#  OrderedDict([('ID', '11519728'),
#               ('Case Number', 'JB532191'),
#               ('Date', '11/28/2018 03:21:00 PM'),
#               ('Block', '035XX W FLOURNOY ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '24'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1152863'),
#               ('Y Coordinate', '1896802'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.872678215'),
#               ('Longitude', '-87.714239472'),
#               ('Location', '(41.872678215, -87.714239472)')]),
#  OrderedDict([('ID', '11516687'),
#               ('Case Number', 'JB528241'),
#               ('Date', '11/25/2018 09:53:00 AM'),
#               ('Block', '028XX W ARTHINGTON ST'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1135'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '04B'),
#               ('X Coordinate', '1157623'),
#               ('Y Coordinate', '1895914'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.870145914'),
#               ('Longitude', '-87.696787454'),
#               ('Location', '(41.870145914, -87.696787454)')]),
#  OrderedDict([('ID', '11500938'),
#               ('Case Number', 'JB507336'),
#               ('Date', '11/07/2018 03:00:00 PM'),
#               ('Block', '039XX W ROOSEVELT RD'),
#               ('IUCR', '031A'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'ARMED - HANDGUN'),
#               ('Location Description', 'APPLIANCE STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1132'),
#               ('Ward', '24'),
#               ('Community Area', '29'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1150133'),
#               ('Y Coordinate', '1894416'),
#               ('Year', '2018'),
#               ('Updated On', '03/18/2020 03:52:17 PM'),
#               ('Latitude', '41.86618435'),
#               ('Longitude', '-87.724324771'),
#               ('Location', '(41.86618435, -87.724324771)')]),
#  OrderedDict([('ID', '11496594'),
#               ('Case Number', 'JB501559'),
#               ('Date', '11/03/2018 08:12:00 AM'),
#               ('Block', '007XX N TRUMBULL AVE'),
#               ('IUCR', '041A'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'AGGRAVATED - HANDGUN'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
# ...
#               ('Date', '01/12/2018 02:10:00 PM'),
#               ('Block', '041XX W MADISON ST'),
#               ('IUCR', '0860'),
#               ('Primary Type', 'THEFT'),
#               ('Description', 'RETAIL THEFT'),
#               ('Location Description', 'CONVENIENCE STORE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '06'),
#               ('X Coordinate', '1148697'),
#               ('Y Coordinate', '1899688'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.880679165'),
#               ('Longitude', '-87.729460332'),
#               ('Location', '(41.880679165, -87.729460332)')]),
#  OrderedDict([('ID', '11202251'),
#               ('Case Number', 'JB113671'),
#               ('Date', '01/12/2018 01:30:00 PM'),
#               ('Block', '008XX N RIDGEWAY AVE'),
#               ('IUCR', '2027'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: CRACK'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1112'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1151237'),
#               ('Y Coordinate', '1905246'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.895881475'),
#               ('Longitude', '-87.719987724'),
#               ('Location', '(41.895881475, -87.719987724)')]),
#  OrderedDict([('ID', '11202252'),
#               ('Case Number', 'JB113605'),
#               ('Date', '01/12/2018 12:30:00 PM'),
#               ('Block', '0000X S KEDZIE AVE'),
#               ('IUCR', '0560'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'OTHER'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1124'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '08A'),
#               ('X Coordinate', '1155056'),
#               ('Y Coordinate', '1899700'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.880586939'),
#               ('Longitude', '-87.706110174'),
#               ('Location', '(41.880586939, -87.706110174)')]),
#  OrderedDict([('ID', '11202290'),
#               ('Case Number', 'JB113685'),
#               ('Date', '01/12/2018 01:54:00 PM'),
#               ('Block', '034XX W CONGRESS PKWY'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: HEROIN(WHITE)'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1153554'),
#               ('Y Coordinate', '1897482'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.874530503'),
#               ('Longitude', '-87.7116844'),
#               ('Location', '(41.874530503, -87.7116844)')]),
#  OrderedDict([('ID', '11202302'),
#               ('Case Number', 'JB113749'),
#               ('Date', '01/12/2018 02:50:00 PM'),
#               ('Block', '008XX N DRAKE AVE'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: HEROIN(WHITE)'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1152564'),
#               ('Y Coordinate', '1905307'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.89602273'),
#               ('Longitude', '-87.715112293'),
#               ('Location', '(41.89602273, -87.715112293)')]),
#  OrderedDict([('ID', '11202317'),
#               ('Case Number', 'JB113735'),
#               ('Date', '01/12/2018 02:40:00 PM'),
#               ('Block', '043XX W CHICAGO AVE'),
#               ('IUCR', '0820'),
#               ('Primary Type', 'THEFT'),
#               ('Description', '$500 AND UNDER'),
#               ('Location Description', 'STREET'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1111'),
#               ('Ward', '28'),
#               ('Community Area', '23'),
#               ('FBI Code', '06'),
#               ('X Coordinate', '1147141'),
#               ('Y Coordinate', '1904970'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.895203467'),
#               ('Longitude', '-87.735038657'),
#               ('Location', '(41.895203467, -87.735038657)')]),
#  OrderedDict([('ID', '11202346'),
#               ('Case Number', 'JB113795'),
#               ('Date', '01/12/2018 02:30:00 PM'),
#               ('Block', '040XX W LAKE ST'),
#               ('IUCR', '0320'),
#               ('Primary Type', 'ROBBERY'),
#               ('Description', 'STRONGARM - NO WEAPON'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1114'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '03'),
#               ('X Coordinate', '1149512'),
#               ('Y Coordinate', '1901446'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.885487535'),
#               ('Longitude', '-87.726422045'),
#               ('Location', '(41.885487535, -87.726422045)')]),
#  OrderedDict([('ID', '11202370'),
#               ('Case Number', 'JB113866'),
#               ('Date', '01/12/2018 03:15:00 PM'),
#               ('Block', '033XX W ROOSEVELT RD'),
#               ('IUCR', '051A'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'AGGRAVATED: HANDGUN'),
#               ('Location Description', 'RESTAURANT'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '24'),
#               ('Community Area', '29'),
#               ('FBI Code', '04A'),
#               ('X Coordinate', '1154087'),
#               ('Y Coordinate', '1894508'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.866358918'),
#               ('Longitude', '-87.709806763'),
#               ('Location', '(41.866358918, -87.709806763)')]),
#  OrderedDict([('ID', '11202372'),
#               ('Case Number', 'JB113775'),
#               ('Date', '01/12/2018 02:34:00 PM'),
#               ('Block', '040XX W CARROLL AVE'),
#               ('IUCR', '1310'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'true'),
#               ('Beat', '1114'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '14'),
#               ('X Coordinate', '1149431'),
#               ('Y Coordinate', '1901930'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.886817255'),
#               ('Longitude', '-87.726706931'),
#               ('Location', '(41.886817255, -87.726706931)')]),
#  OrderedDict([('ID', '11202395'),
#               ('Case Number', 'JB113837'),
#               ('Date', '01/12/2018 03:09:00 PM'),
#               ('Block', '047XX W SUPERIOR ST'),
#               ('IUCR', '0486'),
#               ('Primary Type', 'BATTERY'),
#               ('Description', 'DOMESTIC BATTERY SIMPLE'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1111'),
#               ('Ward', '28'),
#               ('Community Area', '25'),
#               ('FBI Code', '08B'),
#               ('X Coordinate', '1144648'),
#               ('Y Coordinate', '1904544'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.894081814'),
#               ('Longitude', '-87.744205657'),
#               ('Location', '(41.894081814, -87.744205657)')]),
#  OrderedDict([('ID', '11202408'),
#               ('Case Number', 'JB113761'),
#               ('Date', '01/12/2018 02:50:00 PM'),
#               ('Block', '042XX W WILCOX ST'),
#               ('IUCR', '1310'),
#               ('Primary Type', 'CRIMINAL DAMAGE'),
#               ('Description', 'TO PROPERTY'),
#               ('Location Description', 'RESIDENCE'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '14'),
#               ('X Coordinate', '1148174'),
#               ('Y Coordinate', '1898999'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.878798552'),
#               ('Longitude', '-87.731398505'),
#               ('Location', '(41.878798552, -87.731398505)')]),
#  OrderedDict([('ID', '11202409'),
#               ('Case Number', 'JB113935'),
#               ('Date', '01/12/2018 04:18:00 PM'),
#               ('Block', '007XX N ST LOUIS AVE'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: HEROIN(WHITE)'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1121'),
#               ('Ward', '27'),
#               ('Community Area', '23'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1152911'),
#               ('Y Coordinate', '1904810'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.894652045'),
#               ('Longitude', '-87.713851006'),
#               ('Location', '(41.894652045, -87.713851006)')]),
#  OrderedDict([('ID', '11202413'),
#               ('Case Number', 'JB113862'),
#               ('Date', '01/12/2018 03:00:00 PM'),
#               ('Block', '011XX S CICERO AVE'),
#               ('IUCR', '0560'),
#               ('Primary Type', 'ASSAULT'),
#               ('Description', 'SIMPLE'),
#               ('Location Description', 'FACTORY/MANUFACTURING BUILDING'),
#               ('Arrest', 'false'),
#               ('Domestic', 'true'),
#               ('Beat', '1131'),
#               ('Ward', '24'),
#               ('Community Area', '25'),
#               ('FBI Code', '08A'),
#               ('X Coordinate', '1144557'),
#               ('Y Coordinate', '1894679'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.86701278'),
#               ('Longitude', '-87.744788338'),
#               ('Location', '(41.86701278, -87.744788338)')]),
#  OrderedDict([('ID', '11202418'),
#               ('Case Number', 'JB113897'),
#               ('Date', '01/12/2018 03:08:00 PM'),
#               ('Block', '033XX W HARRISON ST'),
#               ('IUCR', '1330'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO LAND'),
#               ('Location Description', 'GAS STATION'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1134'),
#               ('Ward', '24'),
#               ('Community Area', '27'),
#               ('FBI Code', '26'),
#               ('X Coordinate', '1153993'),
#               ('Y Coordinate', '1897159'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.873635421'),
#               ('Longitude', '-87.710081187'),
#               ('Location', '(41.873635421, -87.710081187)')]),
#  OrderedDict([('ID', '11202451'),
#               ('Case Number', 'JB113923'),
#               ('Date', '01/06/2018 04:00:00 PM'),
#               ('Block', '034XX W WALNUT ST'),
#               ('IUCR', '1330'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO LAND'),
#               ('Location Description', 'RESIDENTIAL YARD (FRONT/BACK)'),
#               ('Arrest', 'false'),
#               ('Domestic', 'false'),
#               ('Beat', '1123'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '26'),
#               ('X Coordinate', '1153324'),
#               ('Y Coordinate', '1901462'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.885456607'),
#               ('Longitude', '-87.712423144'),
#               ('Location', '(41.885456607, -87.712423144)')]),
#  OrderedDict([('ID', '11202460'),
#               ('Case Number', 'JB114010'),
#               ('Date', '01/12/2018 05:08:00 PM'),
#               ('Block', '035XX W CONGRESS PKWY'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: HEROIN(WHITE)'),
#               ('Location Description', 'SIDEWALK'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1133'),
#               ('Ward', '28'),
#               ('Community Area', '27'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1153027'),
#               ('Y Coordinate', '1897469'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.874505287'),
#               ('Longitude', '-87.713619669'),
#               ('Location', '(41.874505287, -87.713619669)')]),
#  OrderedDict([('ID', '11202465'),
#               ('Case Number', 'JB113093'),
#               ('Date', '01/11/2018 09:00:00 PM'),
#               ('Block', '011XX S FRANCISCO AVE'),
#               ('IUCR', '2024'),
#               ('Primary Type', 'NARCOTICS'),
#               ('Description', 'POSS: HEROIN(WHITE)'),
#               ('Location Description', 'APARTMENT'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1135'),
#               ('Ward', '28'),
#               ('Community Area', '29'),
#               ('FBI Code', '18'),
#               ('X Coordinate', '1157196'),
#               ('Y Coordinate', '1895033'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.867737038'),
#               ('Longitude', '-87.698379033'),
#               ('Location', '(41.867737038, -87.698379033)')]),
#  OrderedDict([('ID', '11202511'),
#               ('Case Number', 'JB114053'),
#               ('Date', '01/12/2018 05:00:00 PM'),
#               ('Block', '042XX W MADISON ST'),
#               ('IUCR', '1330'),
#               ('Primary Type', 'CRIMINAL TRESPASS'),
#               ('Description', 'TO LAND'),
#               ('Location Description', 'GROCERY FOOD STORE'),
#               ('Arrest', 'true'),
#               ('Domestic', 'false'),
#               ('Beat', '1115'),
#               ('Ward', '28'),
#               ('Community Area', '26'),
#               ('FBI Code', '26'),
#               ('X Coordinate', '1148070'),
#               ('Y Coordinate', '1899674'),
#               ('Year', '2018'),
#               ('Updated On', '05/04/2018 03:51:04 PM'),
#               ('Latitude', '41.88065283'),
#               ('Longitude', '-87.731763004'),
#               ('Location', '(41.88065283, -87.731763004)')]),
#  ...]

# %%
for district, crimes in crimes_by_district.items():
    # Print the district
    print(district)

    # Create an empty Counter object: year_count
    year_count = Counter()

    # Loop over the crimes:
    for crime in crimes:
        # If there was an arrest
        if crime['Arrest'] == 'true':
            # Convert the Date to a datetime and get the year
            year = datetime.strptime(crime['Date'], '%m/%d/%Y %I:%M:%S %p').year
            # Increment the Counter for the year
            year_count[year] += 1

    # Print the counter
    print(year_count)
# Out:
# 010
# Counter({2018: 4066})
# 019
# Counter({2018: 1617})
# 009
# Counter({2018: 2146})
# 006
# Counter({2018: 4113})
# 008
# Counter({2018: 2579})
# 025
# Counter({2018: 2515})
# 011
# Counter({2018: 7234})
# 004
# Counter({2018: 3127})
# 002
# Counter({2018: 1742})
# 003
# Counter({2018: 2341})
# 012
# Counter({2018: 1820})
# 018
# Counter({2018: 2349})
# 017
# Counter({2018: 829})
# 007
# Counter({2018: 3612})
# 001
# Counter({2018: 2363})
# 016
# Counter({2018: 1189})
# 022
# Counter({2018: 1487})
# 005
# Counter({2018: 3052})
# 015
# Counter({2018: 2494})
# 024
# Counter({2018: 1092})
# 031
# Counter({2018: 1})
# 014
# Counter({2018: 1129})
# 020
# Counter({2018: 736})
