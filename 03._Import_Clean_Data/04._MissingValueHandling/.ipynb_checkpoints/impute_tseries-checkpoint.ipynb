# %%
# Import library for file handling
import os

# %%
# Import library for data processing
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
# Import library for plotting
from matplotlib import pyplot as plt


# %%

# Import air quality file as pandas DataFrame
air_quality = pd.read_csv(os.path.join('00._data', 'air-quality.csv'), parse_dates=['Date'], index_col='Date')

# %%
# Display head
print(air_quality.head())
# Out:
#             Ozone  Solar  Wind  Temp
# Date
# 1976-05-01   41.0  190.0   7.4    67
# 1976-05-02   36.0  118.0   8.0    72
# 1976-05-03   12.0  149.0  12.6    74
# 1976-05-04   18.0  313.0  11.5    62
# 1976-05-05    NaN    NaN  14.3    56

# %%
# Number of nullity
air_quality.isnull().sum()

# %%
# Percentage of nullity
air_quality.isnull().mean() * 100
# Out:
# Ozone    24.183007
# Solar     4.575163
# Wind      0.000000
# Temp      0.000000
# dtype: float64

# %%
# Forward Fill Imputation
air_quality_ffill = air_quality.copy(deep=True)

# Check nullity
print('Nullity before:\n', air_quality_ffill['Ozone'][30:40])

# Start Forward Fill Imputation
air_quality_ffill.fillna(method='ffill', inplace=True)

# Verify Nullity
print('\n Nullity after:\n', air_quality_ffill['Ozone'][30:40])
# Out:
# Nullity before:
#  Date
# 1976-05-31    37.0
# 1976-06-01     NaN
# 1976-06-02     NaN
# 1976-06-03     NaN
# 1976-06-04     NaN
# 1976-06-05     NaN
# 1976-06-06     NaN
# 1976-06-07    29.0
# 1976-06-08     NaN
# 1976-06-09    71.0
# Name: Ozone, dtype: float64
#
#  Nullity after:
#  Date
# 1976-05-31    37.0
# 1976-06-01    37.0
# 1976-06-02    37.0
# 1976-06-03    37.0
# 1976-06-04    37.0
# 1976-06-05    37.0
# 1976-06-06    37.0
# 1976-06-07    29.0
# 1976-06-08    29.0
# 1976-06-09    71.0
# Name: Ozone, dtype: float64

# %%
# Backward Fill Imputation
air_quality_bfill = air_quality.copy(deep=True)

# Check nullity
print('Nullity before:\n', air_quality_bfill['Ozone'][30:40])

# Start Backward Fill Imputation
air_quality_bfill.fillna(method='bfill', inplace=True)

# Verify Nullity
print('\n Nullity after:\n', air_quality_bfill['Ozone'][30:40])
# Out:
# Nullity before:
#  Date
# 1976-05-31    37.0
# 1976-06-01     NaN
# 1976-06-02     NaN
# 1976-06-03     NaN
# 1976-06-04     NaN
# 1976-06-05     NaN
# 1976-06-06     NaN
# 1976-06-07    29.0
# 1976-06-08     NaN
# 1976-06-09    71.0
# Name: Ozone, dtype: float64
#
#  Nullity after:
#  Date
# 1976-05-31    37.0
# 1976-06-01    29.0
# 1976-06-02    29.0
# 1976-06-03    29.0
# 1976-06-04    29.0
# 1976-06-05    29.0
# 1976-06-06    29.0
# 1976-06-07    29.0
# 1976-06-08    71.0
# 1976-06-09    71.0
# Name: Ozone, dtype: float64

# %%
# Interpolate linear Fill Imputation
air_quality_ilinear = air_quality.copy(deep=True)

# Check nullity
print('Nullity before:\n', air_quality_ilinear['Ozone'][30:40])

# Start Interpolate Linear Imputation
air_quality_ilinear.interpolate(method='linear', inplace=True)

# Verify Nullity
print('\n Nullity after:\n', air_quality_ilinear['Ozone'][30:40])
# Out:
# Nullity before:
#  Date
# 1976-05-31    37.0
# 1976-06-01     NaN
# 1976-06-02     NaN
# 1976-06-03     NaN
# 1976-06-04     NaN
# 1976-06-05     NaN
# 1976-06-06     NaN
# 1976-06-07    29.0
# 1976-06-08     NaN
# 1976-06-09    71.0
# Name: Ozone, dtype: float64
#
#  Nullity after:
#  Date
# 1976-05-31    37.000000
# 1976-06-01    35.857143
# 1976-06-02    34.714286
# 1976-06-03    33.571429
# 1976-06-04    32.428571
# 1976-06-05    31.285714
# 1976-06-06    30.142857
# 1976-06-07    29.000000
# 1976-06-08    50.000000
# 1976-06-09    71.000000
# Name: Ozone, dtype: float64

# %%
# Interpolate linear Fill Imputation
air_quality_iquad = air_quality.copy(deep=True)

# Check nullity
print('Nullity before:\n', air_quality_iquad['Ozone'][30:40])

# Start Interpolate Linear Imputation
air_quality_iquad.interpolate(method='quadratic', inplace=True)

# Verify Nullity
print('\n Nullity after:\n', air_quality_iquad['Ozone'][30:40])
# Out:
# Nullity before:
#  Date
# 1976-05-31    37.0
# 1976-06-01     NaN
# 1976-06-02     NaN
# 1976-06-03     NaN
# 1976-06-04     NaN
# 1976-06-05     NaN
# 1976-06-06     NaN
# 1976-06-07    29.0
# 1976-06-08     NaN
# 1976-06-09    71.0
# Name: Ozone, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3d3aef1be403> in <module>
#       6
#       7 # Start Interpolate Linear Imputation
# ----> 8 air_quality_iquad.interpolate(method='quadratic', inplace=True)
#       9
#      10 # Verify Nullity
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6992             if method not in methods and not is_numeric_or_datetime:
#    6993                 raise ValueError(
# -> 6994                     "Index column must be numeric or datetime type when "
#    6995                     f"using {method} method other than linear. "
#    6996                     "Try setting a numeric or datetime index column before "
#
# ValueError: Index column must be numeric or datetime type when using quadratic method other than linear. Try setting a numeric or datetime index column before interpolating.

# %%
# Interpolate linear Fill Imputation
air_quality_inear = air_quality.copy(deep=True)

# Check nullity
print('Nullity before:\n', air_quality_inear['Ozone'][30:40])

# Start Interpolate Linear Imputation
air_quality_inear.interpolate(method='nearest', inplace=True)

# Verify Nullity
print('\n Nullity after:\n', air_quality_inear['Ozone'][30:40])
# Out:
# Nullity before:
#  Date
# 1976-05-31    37.0
# 1976-06-01     NaN
# 1976-06-02     NaN
# 1976-06-03     NaN
# 1976-06-04     NaN
# 1976-06-05     NaN
# 1976-06-06     NaN
# 1976-06-07    29.0
# 1976-06-08     NaN
# 1976-06-09    71.0
# Name: Ozone, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-43b40e7f452b> in <module>
#       6
#       7 # Start Interpolate Linear Imputation
# ----> 8 air_quality_inear.interpolate(method='nearest', inplace=True)
#       9
#      10 # Verify Nullity
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7015             inplace=inplace,
#    7016             downcast=downcast,
# -> 7017             **kwargs,
#    7018         )
#    7019
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     568
#     569     def interpolate(self, **kwargs):
# --> 570         return self.apply("interpolate", **kwargs)
#     571
#     572     def shift(self, **kwargs):
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/internals/blocks.py in interpolate(self, method, axis, index, values, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1168             inplace=inplace,
#    1169             downcast=downcast,
# -> 1170             **kwargs,
#    1171         )
#    1172
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _interpolate(self, method, index, values, fill_value, axis, limit, limit_direction, limit_area, inplace, downcast, **kwargs)
#    1264
#    1265         # interp each column independently
# -> 1266         interp_values = np.apply_along_axis(func, axis, data)
#    1267
#    1268         blocks = [self.make_block_same_class(interp_values)]
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377     except StopIteration:
#     378         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/internals/blocks.py in func(x)
#    1260                 fill_value=fill_value,
#    1261                 bounds_error=False,
# -> 1262                 **kwargs,
#    1263             )
#    1264
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/missing.py in interpolate_1d(xvalues, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     309             bounds_error=bounds_error,
#     310             order=order,
# --> 311             **kwargs,
#     312         )
#     313         result[preserve_nans] = np.nan
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/missing.py in _interpolate_scipy_wrapper(x, y, new_x, method, fill_value, bounds_error, order, **kwargs)
#     363             method = order
#     364         terp = interpolate.interp1d(
# --> 365             x, y, kind=method, fill_value=fill_value, bounds_error=bounds_error
#     366         )
#     367         new_y = terp(new_x)
#
# ~/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __init__(***failed resolving arguments***)
#     483                 # Do division before addition to prevent possible integer
#     484                 # overflow
# --> 485                 self.x_bds = self.x / 2.0
#     486                 self.x_bds = self.x_bds[1:] + self.x_bds[:-1]
#     487
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
# Visualizing Imputations
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
nullity = diabetes['Serum_Insulin'].isnull()+diabetes['Glucose'].isnull()
imputations = {'Mean Imputation': diabetes_mean,
               'Median Imputation': diabetes_median,
               'Most Frequent Imputation': diabetes_mode,
               'Constant Imputation': diabetes_constant}
for ax, df_key in zip(axes.flatten(), imputations):
    imputations[df_key].plot(x='Serum_Insulin', y='Glucose',
                             kind='scatter', alpha=0.5, c=nullity,
                             cmap='rainbow', ax=ax, colorbar=False, title=df_key)
plt.show()
# Out:
# /home/doniafrizal/anaconda3/envs/D_datascience-200430-DA/lib/python3.7/site-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   f"evaluating in Python space because the {repr(op_str)} "
